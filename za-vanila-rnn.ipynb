# %%
class RNN:
	def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
		# hyper parameters
		self.hidden_size = hidden_size
		self.vocab_size = vocab_size
		self.seq_length = seq_length
		self.learning_rate = learning_rate

		# weights for input -> header layer
		self.w_layer1 = np.random.uniform(-np.sqrt(1. / vocab_size), np.sqrt(1. / vocab_size), (hidden_size, vocab_size))
		# weights for header -> header layer
		self.w_layer3 = np.random.uniform(-np.sqrt(1. / hidden_size), np.sqrt(1. / hidden_size), (vocab_size, hidden_size))
		# weights for header -> output layer
		self.w_layer2 = np.random.uniform(-np.sqrt(1. / hidden_size), np.sqrt(1. / hidden_size), (hidden_size, hidden_size))
		self.b_layer2 = np.zeros((hidden_size, 1))  # bias for hidden layer
		self.b_layer3 = np.zeros((vocab_size, 1))  # bias for output

		# memory vars for Adagrad - https://machinelearningmastery.com/gradient-descent-with-adagrad-from-scratch/
		# ignore if you implement another approach
		self.mem_w_layer1 = np.zeros_like(self.w_layer1)
		self.mem_w_layer2 = np.zeros_like(self.w_layer2)
		self.mem_w_layer3 = np.zeros_like(self.w_layer3)
		self.mem_b_layer2 = np.zeros_like(self.b_layer2)
		self.mem_b_layer3 = np.zeros_like(self.b_layer3)

	def softmax(self, x):
		p = np.exp(x - np.max(x))
		return p / np.sum(p)

	def forward(self, inputs, hprev):
		hot_encoded_chars, activations, net, prediction = {}, {}, {}, {}
		activations[-1] = np.copy(hprev)
		for t in range(len(inputs)):
			hot_encoded_chars[t] = np.zeros((self.vocab_size, 1))
			hot_encoded_chars[t][inputs[t]] = 1
			activations[t] = np.tanh(np.dot(self.w_layer1, hot_encoded_chars[t]) + np.dot(self.w_layer2, activations[t - 1]) + self.b_layer2)
			# taking the dot product between the activation and the weight matrix -- this is called the "net input" to the current layer
			net[t] = np.dot(self.w_layer3, activations[t]) + self.b_layer3  # unnormalised log probs for next char
			prediction[t] = self.softmax(net[t])
		return hot_encoded_chars, activations, prediction

	def backward(self, hot_encoded_chars, activations, predictions, targets):
		# backward pass: compute gradients going backwards
		d_w_layer1, d_w_layer2, d_w_layer3 = np.zeros_like(self.w_layer1), np.zeros_like(self.w_layer2), np.zeros_like(self.w_layer3)
		d_b_layer2, d_b_layer3 = np.zeros_like(self.b_layer2), np.zeros_like(self.b_layer3)
		dhnext = np.zeros_like(activations[0])

		for t in reversed(range(self.seq_length)):
			d_prediction = np.copy(predictions[t])
			d_prediction[targets[t]] -= 1  # backprop into y

			d_b_layer3 += d_b_layer3
			# dh includes gradient from two sides, next cell and current output
			dh = np.dot(self.w_layer3.T, d_prediction) + dhnext  # backprop into h

			derivative_dir = (1 - activations[t] * activations[t]) * dh  # derivative_dir is the term used in many equations
			d_b_layer2 += derivative_dir

			d_w_layer1 += np.dot(derivative_dir, hot_encoded_chars[t].T)
			d_w_layer2 += np.dot(derivative_dir, activations[t - 1].T)
			d_w_layer3 += np.dot(d_prediction, activations[t].T)

			# pass the gradient from next cell to the next iteration.
			dhnext = np.dot(self.w_layer2.T, derivative_dir)
		# clip to mitigate exploding gradients
		for dparam in [d_w_layer1, d_w_layer2, d_w_layer3, d_b_layer2, d_b_layer3]:
			np.clip(dparam, -5, 5, out=dparam)
		return d_w_layer1, d_w_layer2, d_w_layer3, d_b_layer2, d_b_layer3

	def loss(self, ps, targets):
		"""loss for a sequence"""
		# calculate cross-entrpy loss
		return sum(-np.log(ps[t][targets[t], 0]) for t in range(self.seq_length))

	def update_model(self, dU, dW, dV, db, dc):
		# parameter update with adagrad
		for param, dparam, mem in zip([self.w_layer1, self.w_layer2, self.w_layer3, self.b_layer2, self.b_layer3],
									  [dU, dW, dV, db, dc],
									  [self.mem_w_layer1, self.mem_w_layer2, self.mem_w_layer3, self.mem_b_layer2, self.mem_b_layer3]):
			mem += dparam * dparam
			param += -self.learning_rate * dparam / np.sqrt(mem + 1e-8)  # adagrad update

	def sample(self, h, seed_ix, n):
		"""
		sample a sequence of integers from the model
		h is memory state, seed_ix is seed letter from the first time step
		"""
		x = np.zeros((self.vocab_size, 1))
		x[seed_ix] = 1
		ixes = []
		for t in range(n):
			h = np.tanh(np.dot(self.w_layer1, x) + np.dot(self.w_layer2, h) + self.b_layer2)
			y = np.dot(self.w_layer3, h) + self.b_layer3
			p = np.exp(y) / np.sum(np.exp(y))
			ix = np.random.choice(range(self.vocab_size), p=p.ravel())
			x = np.zeros((self.vocab_size, 1))
			x[ix] = 1
			ixes.append(ix)
		return ixes

	def train(self, data_reader):
		iter_num = 0
		threshold = 0.01
		smooth_loss = -np.log(1.0 / data_reader.vocab_size) * self.seq_length
		while (smooth_loss > threshold):
			if data_reader.just_started():
				hprev = np.zeros((self.hidden_size, 1))
			inputs, targets = data_reader.next_batch()
			hot_encoded_chars, activations, predictions = self.forward(inputs, hprev)
			dU, dW, dV, db, dc = self.backward(hot_encoded_chars, activations, predictions, targets)
			loss = self.loss(predictions, targets)
			self.update_model(dU, dW, dV, db, dc)
			smooth_loss = smooth_loss * 0.999 + loss * 0.001
			hprev = activations[self.seq_length - 1]
			if not iter_num % 500:
				sample_ix = self.sample(hprev, inputs[0], 200)
				print(''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
				print("\n\niter :%d, loss:%f" % (iter_num, smooth_loss))
			iter_num += 1

	def predict(self, data_reader, start, n):
		# initialize input vector
		x = np.zeros((self.vocab_size, 1))
		chars = [ch for ch in start]
		ixes = []
		for i in range(len(chars)):
			ix = data_reader.char_to_ix[chars[i]]
			x[ix] = 1
			ixes.append(ix)

		h = np.zeros((self.hidden_size, 1))
		# predict next n chars
		for t in range(n):
			h = np.tanh(np.dot(self.w_layer1, x) + np.dot(self.w_layer2, h) + self.b_layer2)
			y = np.dot(self.w_layer3, h) + self.b_layer3
			p = np.exp(y) / np.sum(np.exp(y))
			ix = np.random.choice(range(self.vocab_size), p=p.ravel())
			x = np.zeros((self.vocab_size, 1))
			x[ix] = 1
			ixes.append(ix)
		txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
		return txt

# %%
class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output
        
        # memory vars for adagrad, 
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
        
    def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = np.zeros((self.vocab_size,1))
                xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
                os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
                ycap[t] = self.softmax(os[t]) # probs for next char
            return xs, hs, ycap
        
    def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity 
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam) 
            return dU, dW, dV, db, dc
    
    def loss(self, ps, targets):
            """loss for a sequence"""
            # calculate cross-entrpy loss
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))
        
    
    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update
                
                
    def sample(self, h, seed_ix, n):
            """
            sample a sequence of integers from the model
            h is memory state, seed_ix is seed letter from the first time step
            """
            x = np.zeros((self.vocab_size,1))
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = np.zeros((self.vocab_size,1))
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader):
            iter_num = 0
            threshold = 0.05
            smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
            while (smooth_loss > threshold):
                if data_reader.just_started():
                    hprev = np.zeros((self.hidden_size,1))
                inputs, targets = data_reader.next_batch()
                xs, hs, ps = self.forward(inputs, hprev)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                loss = self.loss(ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                smooth_loss = smooth_loss*0.999 + loss*0.001
                hprev = hs[self.seq_length-1]
                if not iter_num%500:
                    sample_ix = self.sample(hprev, inputs[0], 200)
                    print( ''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
                    print( "\n\niter :%d, loss:%f"%(iter_num, smooth_loss))
                iter_num += 1

    def predict(self, data_reader, start, n):
        #initialize input vector
        x = np.zeros((self.vocab_size,1))
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        # predict next n chars
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size,1))
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 25
data_reader = DataReader("texts/input.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# TstzAwBpzs.BhwT!
# odvyW sR.-WjRisWPWx/Y sB)P)cjS)lrppthPtcmNsus!zRC !PsoiIdcs?'ppkvtNIrmlPa-aqulYll?rz,qLPsu.pcntrsTWSsbL)!,gC?-NRqP'IL s/ci-jo-ymcvs sglebcedgYrwU,fyT?SI',Il(PmigjsrTwg sUia)pi.d/sPcB'
#
#
# iter :0, loss:98.295346
# h ne hnpss ahahey insald int, Cl iod ure uoepmhe ngen an unduudamaic ainyas ani r no swuralotn ac fe sd
# iltangha.
# veoterys yhe cldamisoscd  aft asfacs soshaar lapi Isfe d cwrt idus fl aheaNniuuobeac
#
#
# iter :500, loss:90.726713
# euc fofescek cof whals couurs babomd
# nfeilfecrecone raceriod mhamyxur er'ov sibleng ss tonnts.
#
# Whde Psctsyan judet tolondsisillcdexeevinton?ef mconinung sed tioneew inncersmor vkonctoothe Ptonr wexf
#
#
# iter :1000, loss:79.686091
# nmpr thesh /wit mucthe tom.Tvis ws, doct nl arye genres avesd pod plaminis tactuante thar sitedlapteRd conthis ebuton tometars to q m codd ers urchemponer ramure thy intos y is sly bere pesr that to a
#
#
# iter :1500, loss:69.953882
#  cveasctang furh bfeapeftsyonk on ritowe ka uclindtotstary ouplo checepitdersi-g brounentpruty. Anof cj mumruntidicuve ?rif com? yhompl wkcotedotext bile anta ilext mracny and acond cobderuBy kpurong
#
#
# iter :2000, loss:61.706081
# forerd.th wk woth osstobrofwied arary o comphit cexth yo spefed thep lasher auct pofacoh thew tu mracingt fode cofled amp mf
# ctapust copendead as tu he ghessingie thems murang boghat Bomgeand comt?it
#
#
# iter :2500, loss:55.072589
#  thy usito Prethees tofy ucicher,t prethechetond ose thif iosimnags and coneed tewy thi fempest, sont shamale mects muclawe rerolyof th ceftible.
# Cowefas fo poully thew, tint ye,t ptle Prollofesd .
#
# T
#
#
# iter :3000, loss:49.567379
# pous sulled ps.
#
# YIthan chaed couryip he shing oupllis or tompoige that craore codmer ther
# hes, apwlerencsienents andearle componendeterithe strerhin componensteructnacly copsinn ot ef ined wenkstrero
#
#
# iter :3500, loss:44.805796
# We tanos, ao themat intore ing ialied soganictstandiclebe.
#
# Cou camrof woul cinted.
#
# We nerfrithengs aos thoucte isiollicos youp wase stald wlis onects onaseIs dode lashestestianey cory pole ithe tare
#
#
# iter :4000, loss:41.214656
# intfor.
#
# ItLomfolle ony sog in sith one sige coderssat turt, aln is wog.
#
#
# Low in mu ur ancodefonntait then iapl ba ep in mutonllit poneccohesesstontstent, ithe couponenterat ba ch bheate she nonen to
#
#
# iter :4500, loss:37.823203
# pent, wrofrof cublext fompones ther ang -uof ding muct aruof wis in tu and paskes over Pfe foam.s thinct, unper cofopy the sh pleccinerR y sing; kears comeectithew chat is ale asle compou; ie wnche gh
#
#
# iter :5000, loss:34.949139
# errard pustearo amt ines are mhould contefr tage ss anlaind coumerSideas omr ir, and.
#
# What codeaclempothing oupnt cant, steraas of in digery.
#
# The bavictest he y ererced thac inte sinsitkiglenthed th
#
#
# iter :5500, loss:33.266347
#  afriche thim ofss, subloul cohe und mass to unth Nodectly. eter aud component concelys tige components ther cou frompowethar chang clare poould bhow coching code aling ghew tofilliche rodund.
#
# Thesio
#
#
# iter :6000, loss:30.597729
# e foms corke. The rode aritn ave in wotleag acces turkcodeitheks arr cfodectsmalw entoun he angesis sig sowe ing muctepthec toty illing. Rep carcoutlinn ef coup cave botecd pr pectasilied ais yos arce
#
#
# iter :6500, loss:28.189255
# n comure thing er conth coly yon depr foup codetktsithelr sued ae dofficle stmion intesit. Ceats a/sing miley cussinge sing fintewints cthecoore sistsersistes orpest, and ro itor eve araterill it chat
#
#
# iter :7000, loss:26.346259
# t dloull if ces enced aapling. lepren boureth ou dhykithe Simuel cont ma benclle cont re
# t orfeching Bas esuroungito Coutos yod wouthas into boug wy ither?od that thingy sucomyonestohe as main youmer
#
#
# iter :7500, loss:24.638581
# pes oull trof oraveructSinoted.
#
# Tho ?h fer inop edore cooreatscorreaply ifory hou dempthe seftcon weved, wout cait ient os dis ompthand corutor ipersit.
#
# W aveler overr aces the cohess.
#
# The pext ing
#
#
# iter :8000, loss:23.061587
# . The goun ally theain baog depent faoge ind deal ha lore sigh cthes, corm?ealedenges tayl Ba reale ind of neer to ary thay inge thyoun ed poth tuon enderposs fochlrize dy went conte
# Products.
#
# Whe na
#
#
# iter :8500, loss:21.609635
# to khoglectiSP thacstot decung mhom cearly arsull-d paveas emponenctortibly arint coupesion ther wery intody sould cspen semy compeng
#
# The on ouc It concepssswot bas cha s to wee s ments in untoctinuc
#
#
# iter :9000, loss:20.145156
# g.
#
# When ap tore the componentrowlling bou deab tomponenas is Bkall cell cobetRes oncod umpestry.
#
# Cour couply wound ysqwit. Thould anctiep dea s aec bouwing ances onto theite rapkallyon ther? cote.
#
#
#
#
# iter :9500, loss:18.820007
# res ave sohe isstig forslaas one ether wable sserrountiene pamponextsha fomponentsithit.
#
# Pderind aone canvere youle that coduptay. The code the shoule the race that.
# Thenals supknowlinge ticublentec
#
#
# iter :10000, loss:17.964852
# aderes ane you dround ald llammectsy, tige that rhapl cosully in
# mpes? wear cooverreany enthaint th asither thim thy sitod, y.
#
# The yest, wrothe sivery ptery upr fop marconend aoreac inge couprcount e
#
#
# iter :10500, loss:16.792694
# es s yssteade ns plecsint that cemreconsiforerpes mofere s, yry stawitorrexs bit Pfaist at troul arconterface, ssog pontexts wor archil -e. Priareaded.
#
#
# Thes cnow musiss youlict tint camklyo jogeft m
#
#
# iter :11000, loss:15.970713
# e ro uribusiand copurfaces sup shing bpever incep thes.d The code, terethog. The definge thather Bosthieg. Usel wncowlenckass together, dave toblic inte ingale bothe stcapk amuthie inoune, as ontestro
#
#
# iter :11500, loss:14.861293
# e ancems o whes th maly or;er em ine, wout annoinly ercerhe Rpmaintiin if wict whwinved ompont y urhe anced op in mucinh cuatu smacle thake recssien youl conterIting ffapling lfower loupls correct biv
#
#
# iter :12000, loss:14.112632
# u noge cons moductiblll ais axt xall aricfere frpurt cuinted tann a nompodedective ti reakspontogeting tsyou hero. The codents warulien to unde.
#
# They iodether.plit. The crams abpouple wuth overurithi
#
#
# iter :12500, loss:13.589564
# tibgers sifry hep is evublrom ars accenend atsith ou the story is access tohether. Coverinc coner incend poratreacins te with other, on conts anged co cevery pave in cosither, pothe Ithy urfecresh ith
#
#
# iter :13000, loss:12.854649
# atss correst Cou need or eronte, arkak sof inod tamponetronn tespesgling gedy pode courests over ehe thoup compodem? he pang tove reataskesstibly intaint wethy and uncoms,oblingar foncendepthefling an
#
#
# iter :13500, loss:12.128023
#  camponents onge it yound maintain if ur themponentarill conces tanly conally urct you need of wing angemponentaing with e coderctarlyd ro underyone mais contay ssald feat inged omponents evind Ie any
#
#
# iter :14000, loss:11.538680
# to makeve compocenthit wucfor dogh conctestshe lesronde.
#
# The bacess, susit maquld ProductSessento component. Paible yould mew inte peptien thancesstating uapy ofupls fos ore nod ibound sigh component
#
#
# iter :14500, loss:10.972174
# nRe the po ble his ousing on the component's purays commones domacthe Sod feme, wound poce merobethe stheryody arka gund if concofry component oreaced wurchess on th in inge sialite Nony isig tlet xys
#
#
# iter :15000, loss:10.370983
# ofebrive testsRef muk po esitisly )r evenic aliblic Primeratkit pofperathag  ffacs coucrall on wery ang I how couply he the rack that.
#
# The basic sumssis ofpor enctible should o forer ingepcont.
#
# The
#
#
# iter :15500, loss:9.799914
# idit. Protu.
#
# The basisic. The contibly ind mow coupl-derory medr on in woulents. The the nhars todelt mespontain all common wly und iave inteclerants. Nothing.
#
# Thenge pom cou dia d sucon th oh compo
#
#
# iter :16000, loss:9.157339
# tes commerow coru cofurpilents.
#
# Ideadesis.
#
# he jame storec codperant wyour Itary tone hanc suthess sifuctari to enos. Bs o rext arryot ances ta liogether, shargesurigh tortext iss ilef wom to the the
#
#
# iter :16500, loss:9.266659
# e seadlenter nowitved fompung patins toat of nlepll conteig foffecle are unound atnound and maintain if won entess, th enderroflede
#
# Whe stses thy. poge yhegether?
# Product the foner ingallest of cos s
#
#
# iter :17000, loss:9.511817
# e athe d med seag cole inforerifss as andsilarrer smapst ed he understand and lom tigh if surd achor is code ant, sn wly wric intorelly estand kour coduct Bhqubi he tompos componesta lreall inte compo
#
#
# iter :17500, loss:8.717499
#  wig. ghacs.
#
# Couly chably The to rapkit! Prisitecthe deat ifryog ef costory urict wicuer ances th cout hew coupled objects.
#
# It's essentis feneabi ef wot n. Papr arp ive urpestry chaud innes to the s
#
#
# iter :18000, loss:7.994152
# d ampeng.
# Bhaing. Usely mespon anc interfacykogetoryobly iching Pracing ntote herent.
#
# The basic sumucisn es beat im ortint youg to arisiche shor levest.
#
# The baclied annes toge he orger andest amror
#
#
# iter :18500, loss:7.884059
# messs geting yssorporeanid beverestaning booutestiog components onces Nath puld cont of eeve and Productvesitien is the nade ssurlecentep suly sill of ision mofteass.
#
# Ite, pod pestext of inces to he
#
#
# iter :19000, loss:7.325379
#  cane bas of graw.
#
#
# Low cyiw shams the ate.
#
# CouPrind Bfouctthy tour pontions stew. Use would gequlicg tosith ithes, stors to hace. Iued for loare rode weving oritotect, Product efos to wieg.
#
# The ba
#
#
# iter :19500, loss:6.873556
# mpllic ing public of cofry a?nend for aver of coup componentr inseve and compose texts wewis sull for lowic. Borvesisit mative tay. Ithw tould he- toage components.
#
# Wher aon coduraisis and indepther.
#
#
# iter :20000, loss:6.869777
# gext puple in thy.
#
# The bave bes esses sery nout your acterelta sigh component es aple thoun
# Be chans aoce smain if ylacyexts.
#
# The basic summarces sif no cenether lout ant Bour code thy wound surfacs
#
#
# iter :20500, loss:6.267354
# asts on yovict musp unders components.
#
# Whe, spone hau tha inge nasidg ma, s ane commerhapl ined ablit conte context from conteracts with other componeptshecthrurine that conce that how mallyidt ondll
#
#
# iter :21000, loss:5.999473
# idera siag om on isead wny components oncer fecthes to Chousitigllyot.
#
# Nher, ercore cod unt. Prithed pabliald fuchive to teane ro ary compomentro componen abitesion contain ald infecturall oupthar in
#
#
# iter :21500, loss:5.725167
# esio/d. Priorero underotheas arr of cooperathingef cempour enthe stout inoup iog the codert, and ProductSexpriflectSpof in the thowituctsisiquly unce.
#
# The basictss,obiting os on interacts the story i
#
#
# iter :22000, loss:6.470188
# e esponsiger correyly.
#
# The basic summere re components clearly annound all cent itvery nverses common haing fublic sucil coupd dec she cings.
#
# Thery Resibgly uruct context ang ProductReposmancess one
#
#
# iter :22500, loss:5.912945
# eryog bod pou loflit. Pra sing or iner axt irpull chle compompos intass pomalingest.
#
# The basis surhe yofrigeb evenald bourext eruiterstorats fim filp y athar es wuct and Promucly hrigen stone dest, P
#
#
# iter :23000, loss:5.361676
#  why shar ingenter, puche and our oucta diat th urh cound and poplerchin. The rest atlyowler?
# Ptiog te sisus sists betiot of orempended pall ic wethyr.
#
#
# The ama sund concther to Cooget.
#
# The code thy
#
#
# iter :23500, loss:5.034258
# fid kears fote t ge the name testey codeting osuthle y mompos of or chathe suml che sigh of oner context from other.
# Thes that knonlect camp, grat yout pain if cullary complind les mare ro or er une.
#
#
# iter :24000, loss:4.630391
# plioge correctly. It is togetiqgetion th tecom maon interface he desests.
#
# Logesitatest, pur areve is amsopwhe stery ark uadesss ehey chaint one coded thin suan youg to mame seate, cohesyout covering
#
#
# iter :24500, loss:4.670691
#  sems, bounded conog thives anc sullice. Yoverion conthou che sisisig sif!wy, wint your code poull-ding led oule derengiflet, andes todell-.
#
# The basis duwict or interconces cospur cavion the sisige i
#
#
# iter :25000, loss:4.634229
# or erce. Yog moup interoos on yog boungari inge. Uulicined destextiod inte you nede a sunist yogepriflect, ProductService compoce, and poriere noreereffrcorvic pumlored turinit inow annse that coore t
#
#
# iter :25500, loss:4.215022
# g/.
#
# We nnterface hes to under, wing gebot encontint Basestanl iily cos compone caas esur coupling Cour ponendinn offrang of comsterats of ine. Pront dew akcesss.
#
# It's ro reale (SRP) andeplasss cones
#
#
# iter :26000, loss:4.029006
# oupdets of inew smak mornectsink utusts the node. Ithot componentsit if yoncances to cratige that will ende cohe Rerpos compund yofledg bopleblendebat thing of cint if yoreatestivelt the tomposithe st
#
#
# iter :26500, loss:4.674246
# ed modusk dings gotedint to.
# hait kovet.
#
# Wethe's of cing tovecasses and contexts.
#
# What cans defingem to Chec prucled ithed of betess pimof to tha sint contexts why, rhe bepleare hemter.pling m or e
#
#
# iter :27000, loss:4.870225
# ting components complivitaily ing to understand and maintain if we can effectitepti roflect, ahe chepledetRes acceme component's mpout will ouct ancomrisisgestad fourle stu yourfices hige, ing pubgill
#
#
# iter :27500, loss:4.494185
# e Noth ingebler coupling fremporghongether, cancof isic inte commofledw of ro ensifses edrorropleacdusucund tunin - the code that is.
#
#
# Cheenterstestoup a hu Nhant compodent code thy conces thapl comp
#
#
# iter :28000, loss:3.863481
# e annoss oute nhe noo mamponetay thia sif pedill aint, Pracssmances together, stays to whe stsef e urrect, and Pfugha sim! Th wlit The code that serves a commlove arcouru the codents yom dacrey samkis
#
#
# iter :28500, loss:3.458815
#  inhe ancod omponents clearly and oullith un? It wied and contrig punle hever inon ere are components oncode thy stexe subitebine. The about thow ons cunk desponecoss mamponeness of er in wegeas youg
#
#
# iter :29000, loss:3.467301
# d amponents onde to tog coupls coure in tige tactext es compene, at pouc a niges morhe urh conces th code togepinnates that consills ext arr ic inteckaserssit. rompes murp cungs.
#
# The basic summary of
#
#
# iter :29500, loss:3.814566
# pliteet, whew therything public! That.
#
# The basictests.
#
# Ide shat will end aply annole tay thing of cars in togetig endo that is why coded.
#
# The to tog components. It meens esusitod oupones.
#
# It' suff
#
#
# iter :30000, loss:4.074614
#  decodrealetls y comptrercourkagle steare romponentare indert, and your ced pode things get much easier to understand and mainey urfwcumathd.
# g.
#
# The chep if caplere, w whawsinenst efit, couc sew couc
#
#
# iter :30500, loss:3.497802
# or even replaced endapseas of coffengefic interface, covering ever, ancondenas es abies te uns corsigh cohesk, apout tera code that ws whe storka ur enon controtu beves the have underes components.
#
# I
#
#
# iter :31000, loss:3.046978
# gext wou lleplackeaus to understand and maintain if we can effectively hrfectnhe more restricted your access leved, ats componenatithit ourg be copthe urkad ?hep lr ario le story couct ancof medre foa
#
#
# iter :31500, loss:2.728956
# efts the codewtr the codest, and des, as essestinly cod ances to crass, wy urha ie wle coucderastige tevect, ProductService, and pupling ureffocests ess or ifor corieve sle eagssor eve abent youl, Pro
#
#
# iter :32000, loss:2.514948
# ade togy mucthy accans to onterconsed interconges of interand penes to are er ifod thec.p sall The components cllecoures auply concext is.
#
# Thept dupleting de Coupdedribl unhere, and kour code ann the
#
#
# iter :32500, loss:3.976409
# esitg.
#
# The next of caplet enth alite, s ance. Yourkanne isstiglwito nnestes, wew code thy un chacle are sucum bovertext ins urliced meprevill und pomponents wize y hestexts.
#
# The basic summary of the
#
#
# iter :33000, loss:4.587420
# e to wicents one code that sem, annod of clder, writhe thou dofendentict ancos texts feco. Yowlem that thing you dewice. The pothit I howy ur if aro cod warrogett bothevibly testrefteranntessestaccese
#
#
# iter :33500, loss:4.091464
# e annteit Inged ibit inour context from other couthinge siover components onces the wilic. The code. Your commpondeag tige lere. Yowrectests.
#
# Ies esique interfaces she tondeplaces wige the forefing d
#
#
# iter :34000, loss:3.348609
#  ghy und purling. Apply the Single Responsibility Principle (S
# Ihe, (h ir lyatem that clas esurper of codectsse. Cohesint and contes th, concer to ino evecilly tm?Pr components. It boged context in to
#
#
# iter :34500, loss:2.892092
# t yoned or im ontict wous toly yr chitecture daag the domain knowledgy. It mercsuon of ing. It a sif context fryou hand compone, and of ciady tunt Youl, your poductSerory pred inleve wighe sther coble
#
#
# iter :35000, loss:3.057478
# wnc mmonntstand annonectsion cocour jubl if inveres ompose wering on wico isgemsteblyain ingllw of be angefor to ino rooge cofry ancun tadd or il aubgle thaslwith ruel orro ule covel, ats of gheve thy
#
#
# iter :35500, loss:3.001656
#  inhe ances to int ges ther on the component's public interface, covering every pams, se together of cave intorell-define basi iss uly gecos anga siflet cforests chat ing puple in chicterficy ofly pou
#
#
# iter :36000, loss:2.758505
# or er yow change con efurg annting The code. Your code should reflect the architecture diagrams to apmala duchly would beving fow comp cemaon coplepls in tith that.
#
# Then mon? Nothing. Both an. The nh
#
#
# iter :36500, loss:2.369322
# T.
#
# The gath lesting
#
# The code thyos she components andlitvinit of interand kesplings get much easier to understand and maintaid kohesion. Use well-defined interfaces and inversion of contains es copm
#
#
# iter :37000, loss:2.112299
# efos the story is th ing druplin wn inces to create unnecessurs on thy wig. Apply th we tha sestes throurom iaciss wondeg.
#
# The basictestsponed interfaces shit wouk fryithyour patr ave arurectlit of a
#
#
# iter :37500, loss:2.359357
# y, why codewitin. The and cones and iour hoderictmrap enterface.
#
# Then, instead of writing unit to makies componeptint Bastext fritly cenderasket ancests cimple ianth connt entle lou components clearl
#
#
# iter :38000, loss:2.751135
# esitg - the code that is Prackaresie d. g.
#
# The chans to are uapemary thave deflet, paig arp if cunpritucthes together, cais code. Your code should reflect the forpested code thyourh o make to ine nss
#
#
# iter :38500, loss:2.629166
# w es ssucly cis shams wout impysint ilcine it eaty and wess for every publicent, wubitlif cofullit. Prohit. Prowinn sige tast beat you have undeplasies wing ysuthing on the context froup cevedurith on
#
#
# iter :39000, loss:2.252973
# e annecturacosessessaccess you de coount dur. cendent comply me poserperyour, ined the component's publlaces sha d foutext ang unitlycondes that thinistewit toupling mearebinde cone Id gneld, wuct en
#
#
# iter :39500, loss:1.950701
#  gh entext aru unly thew, and contexts wewitve itRef compose tiy component depends on or intera as, depontexts weructshe simponectsigntitly lrigly pleprery hmain ald bann bo enses the ro Repring the s
#
#
# iter :40000, loss:1.752108
# d mumkofetedtion of codprinl cores surlycenda leasis ing duprevities esurka jucp thats comebined masitRepontay s component's public! That deplace. Cogubite ramp ur over os contexts he ondepontay s cod
#
#
# iter :40500, loss:1.687706
# aknenters.
#
# Cotemat coundari if your arching of siflec, tall heat xm the ssurfine rects onces suthy domain. Piogye, commecompone th unlede isterp innt. gher avely is amstReresithe code that bile youli
#
#
# iter :41000, loss:1.582847
# d interfaces and invedy ancorel shes contid oun motesicis condeatictestexts.
#
# The basis le th unatropler, prameess bouce derenthit if yund onogether, stays together, carefully encenss.
#
# The interconne
#
#
# iter :41500, loss:1.469446
# or er yow compoulit impont your actexts mumm, sh temt, Prod centReposising is our for andepthes. Cobleysto enonderavingro boflyctRepromponnt. The neres th you ghouple steasier to are components cous a
#
#
# iter :42000, loss:1.599207
# he components to prefepone winer anderaties ch madd controouss.
# gIthesstnot componens foder rofres, ancod offerit hew puplis ing dfow inged onceptettiblyain if we conces th cohstar e concostowges cont
#
#
# iter :42500, loss:3.717906
# eve urcode anu meverain all classes abor or high cohesion. Use well-defined interfacekr, whe enorlererstand and maintain if we can effectively draw and enforce boundaries during de. Ches sigeb iver or
#
#
# iter :43000, loss:3.828773
# it freplaced sifingy.
#
# We nacr mamion adlinne nofly kvasion to understand and maintain if will context from other of ing.
#
# The decon ant thin stowlent, do anes to understand and maintain if your incen
#
#
# iter :43500, loss:3.030470
# esitg.
# hec sullis that cons kas esion ye coffeconematnealagethed objext wsur. Bote compomponents.
#
# Then, instead of writing douk.
#
# Then, instleall cap anied to make errer inforc med thingstow, yos mm
#
#
# iter :44000, loss:2.392685
#  ro just bour coduct your code and with unotiention ant code that will end up in ad pledentsgeplent, whe Resitory have in common? Nothidg chas inge tha dependeresing on the component's public interfac
#
#
# iter :44500, loss:1.970568
# e annes to orating ysuthe dompos cave into and ot incereated.
#
# The essertody the unfadyopley. Pact and itogetis such easis on or lighe The codebt, and de. Comact conted ta pod of components clearly an
#
#
# iter :45000, loss:1.684577
#  knhepthe cthes tnow tadd popent's erorcodeddeponingacs foreade siat or couth inger to understand and maintain ingent components.
#
# Ideally, we sseasier to maky codithergwinn ald and lothe othe togleat
#
#
# iter :45500, loss:1.602371
# f wompoching one components andis wot wode ent's masit boundersepot aaykess cimply concepcove th wowet anlaced withouss ay high anit aod of cones wit how ouche dofented pomponents onces that your pont
#
#
# iter :46000, loss:1.450271
# pliceextn.
#
# Then, instead of writing unne till icos, context and only provide access to other packages thrount correct yould betiod overy publices onge, mpone, and muhe lere thass cons of iner ao tore
#
#
# iter :46500, loss:1.328664
# y sifly th wy components.
#
# Idearly, po everatisys com inon torrealetes ais ins utly could ais juch esuche unceacthewyrcess, suma, and unnen that thingstew the story is that thing webit innt anc inte c
#
#
# iter :47000, loss:1.262629
# or even;.
#
# Ides te inouns mute the code that serves a components. It means one components clearly annogeto nasies masiting ite coded bodefroblaclede togeting bact as for high cohesion and low coupling
#
#
# iter :47500, loss:1.440062
# gThe pomponene.
# CWecconend win. The am bog dewibit ed cupleareas on sige context from contamind interface.
#
# Then, instead of writingle wonlede isit. Choupled ro mefrofleccha changede icilly thew thit
#
#
# iter :48000, loss:2.527226
# as orepoential toup ann muchith y.
#
# Che ithe essentiand or intarievifurnon tayks of cooperathit contexts we the fowering ysuthed doftwilecod shewsiondefiner are is togetige le endepllacleraineld allay
#
#
# iter :48500, loss:2.574529
# wine derriblly pepes thew ciagever mor? at wricit your couctse plealy consifs andes to craes come, and such a unit do just that.
#
# The basic summary of thaystrery ving that.
#
# The basic summary of them
#
#
# iter :49000, loss:2.124124
# esinge innork thang I omponents clearly announces their purpore, cohesion. Use well-defined interfaces and inverais abnendarreal the components, onosit. Choulg for eraid courith ount ofracen elelit pa
#
#
# iter :49500, loss:1.734190
# y (hain to ent with for high cohesion ing decturas sis. The name cther, thieg to aribull- entarit youp ind pure rabo thasly and intebfechif we couge that chaver of yowit amstsyourpy prould of cing you
#
#
# iter :50000, loss:1.470072
# e and oned concexd.
#
# Lhy yould menas sucthe other components.
#
# Ideally, we should orang reat thevects cos covectint do underess antams in tito younded contexts.
#
# The basic summary of the sssunled prog
#
#
# iter :50500, loss:1.291329
#  conery pund coure that wo knoull and our overrompos turp intosithec, conthed annese component rour access to othen tunt ine iaverk on wiad thaint ontent Pa mughe spour. Pingres componentace that will
#
#
# iter :51000, loss:1.175975
# tithe that onepin thass cung bo the code that changele is ans toupling. Apply the Sing bourhited corieve sterfecestang poupling mabling meflectest component d. Pany that is wiog tubunitlicent componen
#
#
# iter :51500, loss:1.090874
# ats oncode ang ther components. It means one depylit wne stose ibo invery ppemt.
#
# Thever iogerstand and maintain if we can effim context froup ing. Apply thy wether stays together. The code that serve
#
#
# iter :52000, loss:1.083722
# it couting os of coure smarle basic summary of the story is that thingstewit ene. The next in. The enonde cempos rawy and maintain if yllcompocemars iever, insillly unt pamptionsiss snogy able the isi
#
#
# iter :52500, loss:2.897755
# or even replaced without tad bluckasion the ractuys boryine thes the component depends on conteit IuRPrion om on is a sunkllr oncos to inte argef ciplerentibly insstend blic. Checko unces ancess mars
#
#
# iter :53000, loss:2.706079
# TRep tounded irg components once tout code as beginners frameweratssebothe thy sure boun ae the compore, componentsrally, re the codeles ofeacing cout tewry concess oubigle Responsibility Princill ren
#
#
# iter :53500, loss:2.116182
# est different problems, so why unict ofrerothe isued arrillrcoup that code und midd overres components.
#
# Ideally, wewsis context and onders and much more readable.
# Pthe stotithy hour inderacth woun mo
#
#
# iter :54000, loss:1.686361
# ed mace deme, wring deat yould he for hive thes that knowledge in your context from contamithr context and onde.
#
# Then, instead of writing unit tests for every public method of every compone thes togy
#
#
# iter :54500, loss:1.401845
# esythin. Be the next of yo pere boubit iaver, ches cour ponuld.
#
# We node sores surlit if pryour ponent's mpomaing fe cod corain annectssand and maintain if we can ealSinod announces their purpose, and
#
#
# iter :55000, loss:1.211339
# e the Singly wer componen th ar poductera inged.
# ghomped bound atsig if main inges surur stays together. The code that serves a common pubforer interconye.
#
# Ite ponting os on thaw bil cemmonepy ores s
#
#
# iter :55500, loss:1.085944
# e youpling.
#
# Low coupling means fewer inte context and unly to gruquchinges to enonterain ay ereritige taskentaon cont of caplery hict bouc sewer inte yle le rog cing that.
#
# The basic summary or the c
#
#
# iter :56000, loss:0.999675
#  dereddille (SRP) for high cohesion. Use well-definemponentire in yound or even replaced without impacting othe Sing. Apply the Single Restorle.
#
# Ther if wintest ancound and maintain if your architect
#
#
# iter :56500, loss:0.981925
# t much uagle sucresdexther,tibre storyoug te ays is thaaneas map explicitly into the code. Yoveding be wit con efurlit coupling mes campom innoded with unve urp context from contamination and overrean
#
#
# iter :57000, loss:0.938423
# plio Checkout masifill encery.
#
# The andesthan. Usell-ut. Co eto ripp the code. Your code should reflyct, anl dupuad ta e teatibl if yowit akner of y arp components clearlacs, why. Package dave smacles
#
#
# iter :57500, loss:0.887841
#  semlain. The result mall for yoamion outhad. Iogesit.
#
# Thepgit; wit. Pro le compocempos cupueg.tRewite nole con y peprerpeme boundarke. thy. Pachicle steamwor.
#
# Thes, wong murc newit instrout im orit
#
#
# iter :58000, loss:0.847009
# wout coupling mefranc means ont much easier to understand and maintain if we can effectively draw and enfor chatectixe if intarconges antist biver eve stersiogyound. The rapu bound end pand oncepind l
#
#
# iter :58500, loss:0.818033
# TRep tounded context ann courf orercon kerentige ithe dodeland invery publve biouss for anges to endersentass to and learn is muth estacsing fubit ba thecodes ou ffod invers.
#
# Then, do ble code testab
#
#
# iter :59000, loss:0.793936
# ast componenatssPrinnt bound thatsinur, urfereade he stsply cthes to preate rompote, whe component can be changes tvecedes turititvid foteryot inot andeposithed stays togesit componenene derrigh med t
#
#
# iter :59500, loss:3.531553
# ade.
#
# Tve oner aed bout code as sha chissis fectass thearize your codorevellide (Scode cod mtoty ici kavedy andemwonet ably chacles. Us ay ererain inged things get much easier to imhes.
#
# The desurr fe
#
#
# iter :60000, loss:4.019338
# es cour. ba cow tog chans or erand poverais It wige tha sis suckagices duru high cohesion. Use well-definemkoure theur th wo understand and maintain if we can effectively draw and enforce noth concext
#
#
# iter :60500, loss:3.175939
# y botesin ent reptecrharke.
#
# Ider the domain knowle comwing means fewer intercompes centrog for every public method of every class, write unit tests focusing on of conder, wige cod Paces aning lf chan
#
#
# iter :61000, loss:2.366777
# aced duputhyounteling means fele is ais domestexts.
#
# What do ProductRepository and BasketRepository have in common? Nothing. Both address different problems, sofew ingadize aon ingamstossogr of cooper
#
#
# iter :61500, loss:1.807303
#  roupling bes flametsepo maon ann fodems, s few isgenouly frameatr of coher.plitl aneress of o ervine andercory.
#
# g(xpne ianly concess maritvife coded bounded contexts.
#
# It's essento your code and arf
#
#
# iter :62000, loss:1.443660
# t. Prap endepones th compenent, wint ysurka chapge covedy antara if yontexts.
#
# Londecturfoup aed io means fode eres componlit im the essential to organize your pach mopess and mualemar esurhice.
# Coup
#
#
# iter :62500, loss:1.203282
# ationde, abutill rouget. Choted.
#
# Theceddipl te unces to creckaut my article about effective testing
#
# Components with a single, we defucgimpllange temat with a sess you d wectsRes clearlico.
#
# Ther aod
#
#
# iter :63000, loss:1.041929
#  ia leply onceryounectasing on with othans of conte. Yofryof mh we are codertect. geply weplis ing de coheconses ou d the inte cod wo Pach should reflect the architecture diag.
#
# The basic summary of t
#
#
# iter :63500, loss:0.932422
# or even replaced with coup context from cthenss.
#
# The caple ing the athe tegreate, and ProductService, ProductSeficin ald enoh coucess masigititory foderained bout wewill cenges enothe dofing deat you
#
#
# iter :64000, loss:0.864203
# Text wing to liur coup in together, caas makigreat inot ecom onents clemroge arcucesteres enteinn orke is a nestand endept our in wher, stats the domain knowledge in working cogy pro pevedant and over
#
#
# iter :64500, loss:0.865583
# estr context and unly thewit iog arplcore teffrcompone torething une that cound undeponoreacy.
#
# Then, instead of writing unit tests onge in y hode youliclessessemare readlit id public! Thqm othe tay t
#
#
# iter :65000, loss:1.437588
#  o Reforetrobint ount and overy pave is cos oftoriersyonethor. Couc messinge wibg madi masient of controb for low sisitly into the code, surly, rhe.
#
# The, and Progelin. tom thy temt, and Prom couthe c
#
#
# iter :65500, loss:1.488740
# dsith ohat.
#
# Wheat torricing rsurlacyextsos oneed to ka en enteran biuld no nter ars one nopyevinge the deplig. Pra sige th y to noth teving depresitn we oricte are sicuides to create unnecessary depe
#
#
# iter :66000, loss:1.244808
# y iog thes the wable should contay sighe stompoded.
#
# The essertorke the complit interface.
#
# Then, instead of writing unit tests for every public methontanne theply components.
#
# Checotleracseogs to cod
#
#
# iter :66500, loss:1.045387
# e annose herersiont of the esstroust and ieverryoune digepes and inversion of capont torencing that.
#
# Thengetithary oster of sigeb mhru lrould bo togente, ,os shec.
#
# The boun ays on caplure, atr of er
#
#
# iter :67000, loss:0.910534
#  rouwler, wlice. Coveriog the charres chathy sorleve. Theple conceatly pungerorcongeflecthess cha sigh context from contamination atnes to understand and maintain if ou tarith ount panc siflyct, and c
#
#
# iter :67500, loss:0.821362
# si
# gCour are couply intice mests and oupge inver context froulling underrerull-e storyouned interfaces and in toss ane cemad wing that knowledge inderstand and maintain if we can effocthe domaices fec
#
#
# iter :68000, loss:0.759755
# pliod to ane llec pommaccing one code. Your code should bef cencros constaid tu bou hammacls Promponntectimp suray greapleving. Apply thaod pohes to understand and much more reasis on such component's
#
#
# iter :68500, loss:0.719904
#  conce touthy depthy urh isiane syones arricos she codew ras aod contectseand and louply conces to ain esstine that. Use y bevigve ur components.
#
# Ideally, we should aim for high cohesion. Use well-de
#
#
# iter :69000, loss:0.689909
# to enoseade th alit. bog macte tiag to cress, wr orceng forelinn. The result is a system that consists of cooperating but independent, bounded contexts.
#
# The basic summary of the story is that things
#
#
# iter :69500, loss:0.666474
# TRep ssumpoderather of a specific domain/context ang os caples, unctingy. gote in enting ProductRepository are highly couges shout thit conthe temptidenteblal, or isteas tuging ntact yos d wo jus cont
#
#
# iter :70000, loss:0.649501
# asin with othy thing unk frepeve lere tesing ysurict yest ak very packa enterconge composed inon torreapeti-d oupd the thing pupined boundarse correctura suting pubit hathes togethergpcowesig. The cod
#
#
# iter :70500, loss:0.634893
# it ysuc.
#
# The chop story is that things get much easier to understand annos to iney to the context from cout histo group thiog ther or macyoup the components the racr gesthaped wekasker ances to cray.
#
#
# iter :71000, loss:0.622553
# esitgit.
#
# By are ufiy howe you hang mas chassessen ouplinRe camm ofundade able sserg coherged or even repturacks on ass conente smar eve ably chacresta smarsesstilllyo juse that.
# The wict yhatlin Bos
#
#
# iter :71500, loss:0.616248
# d ontery preasis Prompodect, Productqmorgeas mount bithe chealion to iner to uns corpesgroug are are uapymarke arvery pubing ulu noftoble io ghoges once tableansexts sitict rour icle ing wey things ge
#
#
# iter :72000, loss:1.836782
# e youpling.
#
# Low coupling m anse concertais that knot, and in turill me. Yompose conced orpergres onog of ie inveructs with access level, the fewer chances to create unnecessamad thew couplingre theuc
#
#
# iter :72500, loss:2.366114
#  postry wiclenista spawe ioverint compot cant conent da thesion - the components.
#
# Ideald condrich component dary chathes wint your to make eveagit youp in cofuch more readable. The names muply interf
#
#
# iter :73000, loss:1.847223
# ting uth ach correctagrtitRes tovericle tha deatRempos camponents will inevitaxl debigge ss frearcod ing our coduraccess level, the fewelit into and of carkale simp uriting ututayk reare concept memts
#
#
# iter :73500, loss:1.409283
# pes enod theclait mollicentiak gests fre uplesk haple (Scode component cam bofryot crigh context fritext fromuctatied to understering onged annects toge in your context from contamination and overreal
#
#
# iter :74000, loss:1.113804
#  semoresstay tedublive iog no an erge just deveces arectestoblactectins ant to racel s of capont turl fffally casist yo licles evenali if cemalit conmad, innes to be rably plimes ablit cant components
#
#
# iter :74500, loss:0.921482
# or even replaced dit codreplangerorrecruct yout code as beginners fif yuas on o hopeduint, ProductServece, khoned pous thyot impacting other, cther orers fing Bo? Cooget coworullen, and I smain and ov
#
#
# iter :75000, loss:0.796368
# The dace context from chreacedass.
#
# The basic summary of the story is that things get much easier to understand and maintain if well-definer as tohes.
#
# It's erpone. Cohesion wn level, the frwer chay i
#
#
# iter :75500, loss:0.713857
# as onde, maise semd, and Paoget.
#
# By notroplesithit contexts.
#
# What do Producthe code. Your codulg sses onse la er in witill-defined purpose are siching of cing your code as bo incercodad interface.
#
#
#
#
# iter :76000, loss:0.657118
# ed mapy ofrayr Baskit togeting luyit iaver, cheryccings th armests of er ichery tucknhomposed into smaller com?onist coutectl uncestayse shais togetoratreatectisg yougeciss in wit yode tifulit. Protit
#
#
# iter :76500, loss:0.618209
# esitgit indepeplefeny.
#
# The basic summary of the story is that things get much easier to understand and maintain if jestext, woget chive ublesk hingCouling mackandeconsiste are composente samp intains
#
#
# iter :77000, loss:0.596786
# c motores ant blgithergepleractsterelt ene ithe fontadd atsmmitRepled oble one ith temption and overreaching from other conterRes togedery ur co plyodr cimp io yog. The code that serves a common purpo
#
#
# iter :77500, loss:0.866687
# e ancep hoser. Ithery, and des cumaon suchandis we that wo Itey or even replecreshesstald atsit muc in mmating un intere illasys corpese components will inevitably interact wning bever, indectura oubl
#
#
# iter :78000, loss:0.918619
#  rore basictss, th thea leatucon effecting your to are uniy tosithe shaino teructuring your code as beginners framework tutorials once taught you.
#
# By now, you should be capturing the domain knowledge
#
#
# iter :78500, loss:0.804025
# tu
#
# Couplings to mlay coupling. Apply the Singl. Pebit invertext ofo sistess.
#
#
# Compone, and ProductRepository arect no nogely isilg morieviner into dest.
#
# The basic sewrais together, carroully or eve
#
#
# iter :79000, loss:0.705363
# atubient sto thecos siflyctsRP) unnone nor thone that.
#
# Then masigne thout howura shece, and duconnes to inessio yhed on ext ir thatyopleacd context from cefoupes cant conth to with op merror endepond
#
#
# iter :79500, loss:0.638986
#  ineas evurarily sys com daal conssing ddowling de theurentiak gestige coherrepl inveruss an hound ProductRepository arectsyople is a codems, into boted.
#
# The more restricted itves, bof er int ceved b
#
#
# iter :80000, loss:0.593000
# or even replaced without impacting other components.
#
# When software is decone dupely dreat explich moreererfaces and inversion of control for low coupling.
#
# Low coupling means aly anserin - the code t
#
#
# iter :80500, loss:0.560740
# TRep masies musitiyg mor? co clearly urkane bote code that serves a cos surh morer theveclerk thesion - the compoulling masifty oh cfor control for high concesilg tos con imroogna gesusit. Checion cod
#
#
# iter :81000, loss:0.538452
# evesurithing purhe hounde andelt, ing tililly coupling. Apply the Sinllef rectamsitReply ghat will anderacts weat access mour code all and wy phind The resplconcenduss cingster esuruply.
#
# Then, instea
#
#
# iter :81500, loss:0.523884
# ed masyes components.
#
# Ideally, we should aimp er cod anctistade itReraor lapresis with ake rerfacesis ou capm onnog dew ifowercon? Netha sis such ullacthet wnicha mull ine ither corpestRProductSeroti
#
#
# iter :82000, loss:0.589166
# esitgit and I howy urkigesk, wur eviner of ing. gherion conthinget, unceptleantsed conces tant es access level, and interfaces and we hatly foreffective tsstoplext the architecthe domaine tha single,
#
#
# iter :82500, loss:2.571461
# c adyoup the story is that things get much easier to understand and maintain if your architecturacts with other components.
#
# Ideally, we should aim rert and wer shay togp ing. Prowit. Pro pomuncendert
#
#
# iter :83000, loss:2.279503
# e anco that changes together, caraoverk thever esuth candegeflyctnder compomerathe stoty in thes tey tedubling und frouplingle strand abot eve arill is a s susingllerroblof d ampos ouwing thainterythi
#
#
# iter :83500, loss:1.722122
#  wog. Paplial for high cohesion. Use well-defined interfaces and inversion of control for low coupling.
#
# Low coupling means fewer ting as oned context from cont miot to leak ghe inoryesifode the code.
#
#
# iter :84000, loss:1.290621
# s pewing yooget.
#
# .
#
# The roduct, Prole is anness bounded contexts.
#
# The basic summary of the story is that things get much easier to understand contais and maintain ingll, contexts.
#
# What do ProductRe
#
#
# iter :84500, loss:1.006467
# plione dereng forelly.
#
# Then, instead of writing unit tests for every public method of the unit. Checkout my article about effective testing
#
# Components with a single, well-defined pubigle ssmald and
#
#
# iter :85000, loss:0.827413
#  canld ara way explicis Nethinc. thed of ave as domyoth no unitict couther acoucinde, ponectheals able sto siceind ghay other onces to cleasis on components.
#
# Ideally, we should aim for high cohesion
#
#
# iter :85500, loss:0.711105
# or even replaced without impacting other them couplinge toffry compend dearly andems,ry. hewendaur components ches enstowit youl thit hesterythin aing es commathesitit much rest, ProdectSopunced ifor
#
#
# iter :86000, loss:0.633708
# TRe
# g ther?
# Product the architecture diagrams that you draw.
#
# The code that changes together stay Singly ceprigh concesy Theveris wenderactt and context from contamination and overy public mpthy siste
#
#
# iter :86500, loss:0.580721
# a undarsing main is che siffites ofectur bout wing bog the things get much easied to he unnes to are ifore conces th context from otherorneryod anderstosion mfectestontays commoneprer onnece. Thant mu
#
#
# iter :87000, loss:0.542959
# ed masses of a spes acces componet if y pess, systentod le thy concontaon conent your poup iforeacinte coderather ha d fearcom onenden simur thew couthy todr ciag whek to understand and maintain if wl
#
#
# iter :87500, loss:0.515834
# rsianler it tige in toge inoull for ences th arkests of er ian. The nepender components, these componentsig Inges th we racr and context from contameratsig pof caane fefer your thy er ancesss cour cem
#
#
# iter :88000, loss:0.495429
# ctesurped of writing unit insif cence. Cohesiot concof demarcess togetsef rrof cevedy beatr sigh concess ls onces th cohes shat constais le rom ouctand and maintay and wulling m antererfaces shouronne
#
#
# iter :88500, loss:0.479630
# aced derecth eforeit coupling m aldererface hes riil tests fod wa gesiend conpleforeatiot yogen. Use well-defined interface, covering every behaviour of theructhe essentoryouC to arest inges ofre the
#
#
# iter :89000, loss:0.467952
#  rore ball require cleare ne invertibly intade ssuthe comporective tuctict yourcod one component can be chaver components, the essto istans together, cais ing urestebinces th iveress.
#
#
# The boun ariti
#
#
# iter :89500, loss:0.458362
# till rougher sos.
#
# What of mriog that.
#
# The bofrititiog ffeconcepssrand poponterad bound on compoulit inctu fod anction anc cent componentsrerour to are iogrexthone tes, beha isit. Thempontiply to ine
#
#
# iter :90000, loss:0.449100
# plicee semas Productnteratre coupled the, wole cemarit tes me uhat hound in ture und ull acu components, these componentses components.
#
# Idealle llcoult baskes of a s com ouy thew cons of such codests
#
#
# iter :90500, loss:0.443134
#  intemactedfracingqum shaty pom thar the group them together?
# Product, ProductService, and ProductRepository are highly coup ing.
#
# We cave arh components clearly announces th ings to a effecting other
#
#
# iter :91000, loss:0.439079
# that thing des, wit mung ull cor estaysext ass undereddion torros comprifly accand ducomposedtint and one change componentsin. Bestoule endars contorp coupd wit coure the coderstand and much more read
#
#
# iter :91500, loss:0.449335
# T to to realetesurition and muth components, os on temamponend. Ppchaver context from contams that yould ufly ac?
#
# Coully.
#
# Then, instead or entod chmaly heng bovecthed kounded abug.
#
# The cher coherve
#
#
# iter :92000, loss:1.632914
# as one starnonstents to etrer ontict oturcob turnoptitestaple io Checkout sy ar lo ho chac is mecommaachisur ave sther poupledfwy ande things get much one.
#
# Ideally, do essers, bountreatestithetRer mu
#
#
# iter :92500, loss:2.101697
# ll-defined purpose are eapy to code tha durs and co. h gep siwhe erext depesiend wnewitly conend comros deplesss comed bounded contexts.
#
# The basic summary of the story is that thit. your access level
#
#
# iter :93000, loss:1.717439
# text and oullaw.
#
# By pyound andodeacin isia se higen softing couct maller.pliy. Ppilit. Prohit. Pace context from contamitars of wreatestititiple (SRP) for high cohesion. Use well-defined interface, c
#
#
# iter :93500, loss:1.301011
# ctestons together. Cohesion is a pretty simhethed tu witlit. Chomponbet.
#
# The code that changes together stays together. The code. Your code should roflect, ProductSerRew caup annted.
#
# The mod waes to
#
#
# iter :94000, loss:0.996899
# ametorke ithe bound ponderr am omuriciss cor efuch mory codelit dfinopys all arict public! Thay other, and it the cempon mavedy.pletien to all context amu storelithe innes together, carefully entara i
#
#
# iter :94500, loss:0.797982
#  poupder, cther there, and ProductRepository are highly coupled; why would not you group them? Cohit cont compone. woruct, wno eforcon?es cometobleain if your architectestably shes thy urhe and overr
#
#
# iter :95000, loss:0.666408
# s domesisn amstr if one rhe nonspons sseflice. Cohecting yohesictied arricts are uoderass to understand and maintain if we can effectively draw and enforce boundaries during deve isverrofand thy urf c
#
#
# iter :95500, loss:0.578628
# plicee starito inglly chacrest components.
#
# When sto code.
#
# Then, instead of writing unit tests foupeshe sthandist things get much easier to understand and mall context from contamint components.
#
# Ide
#
#
# iter :96000, loss:0.520974
#  concod oupleracts with other components. It means one component con e your code as de inoul conce ither compling m ta ins ourinction wing couct surition and overreaching from other contexts.
#
# What do
#
#
# iter :96500, loss:0.481803
# or even replaced without coupling means ofpontr of and corpes of inte, work ontedint one lim ray. Packagesis rasl components. It means one component can be changed or even replaced without coupling me
#
#
# iter :97000, loss:0.454457
# T
#
# Bnt.
#
# We ne tirinit es tory uruct bageereposithe foreling lf compod chive ifec to sicem tay. The result is a system that consists or overy public motho shay dont ampot cad depry. gheld andems, code
#
#
# iter :97500, loss:0.435396
# est de Proturich thati
#
#
# That.
#
# The Pafs shem together, carefully encapsulated.
#
# The mory pout coupling means fewer interconnections acrosstent.
#
#
# Wha, the nonenes. Thepel-y. Co pat. Propteare ing ump
#
#
# iter :98000, loss:0.420800
# aly conit.
#
# The codedtr.
#
# The ching thergen luply interfaces and inversion of control for low coupling.
#
# Low coupling means fewer interconnections across components. It means one mamseptsyou The stork
#
#
# iter :98500, loss:0.410013
# es entesdesithe nou ha e shruct couthou caple ompont amponents.
#
# Ideall on mponented purat sista steasisit tust om thy iog une componented.tPra desucthe Respons onecting the domarail th tuat inour cor
#
#
# iter :99000, loss:0.403227
# ctestons together. Coh compos wereld rearlicem taritit. Proup mompobitesurssion tari isith ro th cout how much one components.
#
# Whentext and ono no yod overreacndrem arcess on serally into ays on cons
#
#
# iter :99500, loss:0.396662
# e annos to ine ervice, and ProductRepository are highly coupled; why would not you group coupling m alier luckagre that wo Prays, wreded whig mach components, these components wit much mactedtothone s
#
#
# iter :100000, loss:0.392659
# u nhe rompos baco the arnoge component depends on or interacts with other components.
#
# Ideclare ta ins mounded iogebos eblectestictive testipl des componendare tha le sicem tann and mofory arcforealed
#
#
# iter :100500, loss:0.386452
# tict your access level, the fewer chances to create unnecessary dependencies that isIt turnones che yoog ohe context from contate as tner comain nogrerpos deabeats one, and suche come, and coderable a
#
#
# iter :101000, loss:0.379917
# pliteyodefecon smak ting en the next ing utisily depy other components.
#
# Ideally, we should aim for high cohesion and dompo nothaved conts.
#
# Reple conet ancomrectes, boutes esurcos erer code that chau
#
#
# iter :101500, loss:0.375660
#  ineas of control for ligh cohesion. Use well-defined inneceasurg bim lain if your arcucother contes thraoge and in pore and ind remarges simple concept, and I hope you have understood it already.
#
# Co
#
#
# iter :102000, loss:0.373300
# or even replerreco that.
#
# The basic summary of the story is that things get much easier to understand and maintain if we can effectively draw and enforce boundaries during devicis deplerrectly. Packag
#
#
# iter :102500, loss:0.369379
# TRep masies sumpll cod pand overrercomrore are ling I to are cocrectly.
# Ppoticts Preplaced without impacting other components.
#
# When seftontexss.
#
# Low th w the code ia yracseas enoturing would bevith
#
#
# iter :103000, loss:0.364975
# as one storne thesion - the code that changes together, stays together, carefully encapsulated.
#
# The more restricted your access level, the fewer chances to creatly cleadd unfere ince components.
#
# Ide
#
#
# iter :103500, loss:0.361015
# ed masy to understand and much smatlwit code thit code that changes together, stays together, carefully encapsulated.
#
# ...
#
# We need to resist the temptation to make everything public! That is why codebases turn into a mass of interconnected object
#
#
# iter :1240000, loss:0.054444
#  coucha componj cole conce taught you.
#
# By now, you deas we thally need to lefer, and into ans ctogether?
# Product, ProductService, and ProductRepository are highly coupled; why would not you group the
#
#
# iter :1240500, loss:0.054221
# or even replimed sthare ra laced cfilg you nee strand I ho bo yo? Product, ProductService, and ProductRepository are highly coupled; why would not you group them? Cohesion - the code that changes toge
#
#
# iter :1241000, loss:0.054235
# The your the component's gevig th to understand and much more readable. The name of such components clearly announces their purpose, and such a unit do just that.
#
# The basic summary of the story is th
#
#
# iter :1241500, loss:0.054068
# a w control for low coupling.
#
# Low coupling means fewer interconnections across components. It means one component can be changed or even replaced without impacting other component depends on or inter
#
#
# iter :1242000, loss:0.054065
# ed mothore. ges ro enorucillict wo stsyog sventict publinle (SRP) for high cohesion. Use well-defined interfaces and inversion of control for low coupling.
#
# Low coupling means fewer interconnections a
#
#
# iter :1242500, loss:0.053886
# dectRpubog un to maced macthe co beverves togeverit your architectural ideas map explicitly into the code. Your code should reflect the architecture diagrams that you draw.
#
# The code that changes toge
#
#
# iter :1243000, loss:0.054558
# cle announces their purpose, and such a unit do just that.
#
# The basic summary of the story is that things get much easier to understand and maintain if your architectural ideas map explicitly into the
#
#
# iter :1243500, loss:0.053676
# entico your code as beginnerster, and yo? lows on commanc shanges ances th arcould componentarsit It all con couct as once th unces th we rif yowet wicles correcthyos sher the Sisilly th wr tawe that
#
#
# iter :1244000, loss:0.054458
#  kasunde invery bnom thad contRes wige that will end up in a big ball of mud.
#
# We need to resist the temptation to make everything public! That is why codebases turn into a mass of interconnected obje
#
#
# iter :1244500, loss:0.054502
# sid.
#
# The code the kny.
#
# The pople is enteract pund and yfor, yould a auc pequed coraes simpls concecturacts with orporerfices dupl- shes ro extes tarntents fearly chathe components.
#
# When software is
#
#
# iter :1245000, loss:0.054278
# pes your code acsing y houlictes masit things to arurech mapy he code that serves a common rabisisin context from contamination and overreaching from other contexts.
#
# What do ProductRepository and Bas
#
#
# iter :1245500, loss:0.054367
#  comply code con efully imlevint onet.
#
# The empontiog overrebuging ulitly contadd and mura layrext wit your co urkandey toodecthe nounit thing public! That is why codebases turn into a mass of interco
#
#
# iter :1246000, loss:0.054145
# or even replaced without impacting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it will require clearly defin
#
#
# iter :1246500, loss:0.054158
# Textsille te fecrive tohe bout im ofpo istenting ysur ake rherythy things get much easier to understand and maintain if we can effectively draw and enforce boundaries during deve is ont depentemt, wno
#
#
# iter :1247000, loss:0.053990
# ave urctions onon to licem ans dore, and more readd onf ycomponent. Theryorela, yourain mact nohethereriticly pabict bou crepter, ishar into ans once. Yowing onj codulit do arkassey too ende win ha le
#
#
# iter :1247500, loss:0.053991
# ed mound the ghim. The code that serves a common purpose stays together. Cohesion is a pretty simple concept, and I hope you have understood it already.
#
# Coupling is the next important thing you need
#
#
# iter :1248000, loss:0.053801
# dectsinit io inountinu tavedy pave sif component draylicents fee component's wompontain ouc chaneratint anctinntedr ctewictmrall gentsie th uner ac undectespons mapk ofuratid.gThe basic summary of the
#
#
# iter :1248500, loss:0.054526
# ticter, dratedtsefreat thing you decorencessyog on e that.
#
# The basic summary of the story is that things get much easier to understand and maintain if the code that changes together, stays together,
#
#
# iter :1249000, loss:0.053604
# e youndarit ifly arly chans to amuncences simple concept, and I hope you have understood it already.
#
# Coupling is the next important thing you need to learn correctly. It is about how much one compone
#
#
# iter :1249500, loss:0.054408
#  rouchanges to crees, y. Cohedinges together, stays together, carefully encapsulated.
#
# The more restricted your access level, the fewer chances to create unnecessary dependencies that will end up in a
#
#
# iter :1250000, loss:0.054446
# sid. ke of cour pung bouc hew will ine ianles together?
# lI muring the dode and wh oundencobly we simet, yourha inow cuns is your context from contamination and overreaching from other contexts.
#
# What
#
#
# iter :1250500, loss:0.054213
# plitedrore com offrcomrone tor thawitile leark tamrectRestot yourdacsiog othes, sveriot your arcom daal components. It means one component can be changed or even replaced without impacting other compo
#
#
# iter :1251000, loss:0.054287
#  canl clansiog fecom thy urkag.
#
# Lhy tinly momeratitoretsifill- to Cothe that your architectural ideas map explicitly into the code. Your code should reflect the architecture diagrams that you draw.
#
#
#
#
# iter :1251500, loss:0.054053
# or even replaced without impacting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it will require clearly defin
#
#
# iter :1252000, loss:0.054048
# The yous wind ithing public! That is why codebases turn into a mass of interconnected objects.
#
# It's essential to organize your packages correctly. Packages should contain all classes of a specific do
#
#
# iter :1252500, loss:0.053853
# avinge thot cfungrentsieg th ackasion. Use well-defined interfaces and inversion of control for low coupling.
#
# Low coupling means fewer interconnections across components. It means one component can b
#
#
# iter :1253000, loss:0.053832
# ed mothore. ges racle, ath components oncef ory.
#
# Coupling lsyou haver components clearict beves, y anga u sts ons should aonects andes to are codg to er yowe shey together, carefully encapsulated.
#
# T
#
#
# iter :1253500, loss:0.053602
# dectsinis to learly and intor in ams of yowither stays together. The code that serves a common purpose stays together. Cohesion is a pretty simple concept, and I hope you have understood it already.
#
#
#
#
# iter :1254000, loss:0.054327
# yr, and unnts to unthe und purplduw components.
#
# Ideall of mmakntsil you ne pain if ymare iconceplars together, caref of code that ino pomposithesstond and mact conteralic! ro she arnes together?
# Prod
#
#
# iter :1254500, loss:0.053349
# e youply ine taml-dalingf your architecturacts wecuncess ass ady thoul ingerur bound with uitther components.
#
# Ideally, we should aim pagu it your acouc ia lewe is ents all componed interfaces and inv
#
#
# iter :1255000, loss:0.054123
#  kagecrictly ur changed or even replaced without impacting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it wi
#
#
# iter :1255500, loss:0.054109
# n th ach context from contamination and overreaching from other contexts.
#
# What do ProductRepository and BasketRepository have in common? Nothing. Both addrersspes components.
#
# Ideally, we should aim
#
#
# iter :1256000, loss:0.053840
# pes quedy what thiog thent sas your po re (s aved fewe is ant ithy tontectss, wode es anteraine bas inges to Prodectsit.
#
# Theng or uny. The namp contexts to lea component component depends on or inter
#
#
# iter :1256500, loss:0.053854
#  campoyeptstans together, carefkout re are code to understand and much more readable. The name of such components clearly announces their purpose, and such a unit do just that.
#
# The basic summary of t
#
#
# iter :1257000, loss:0.053594
# or even replaced without impacting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it will require clearly defin
#
#
# iter :1257500, loss:0.053533
# The yous wind ithing public! Thay ithw. The result is oh ians once thot coun ke ramk he the cempon mannes to clerke youl ael context from contamination and overreaching from other contexts.
#
# What do P
#
#
# iter :1258000, loss:0.053302
# agl of o arcunctigen stotaint if arntays fouplery pacing mamyonent correctly. It is about how much one component depends on or interacts with other components.
#
# Ideally, we should aim for high cohesio
#
#
# iter :1258500, loss:0.053234
# ed mothoremtout will encendedtonle endentict ente che innec argess maprerall isit ta ente, workes snans on weane component depends on or interacts with other components.
#
# Ideally, we should aim for hi
#
#
# iter :1259000, loss:0.052967
# de hrigh yound puplid; why group them together?
# Product, ProductService, and ProductRepository are highly coupled; why would not you group them? Cohesion - the code that changes together, stays togeth
#
#
# iter :1259500, loss:0.053665
# wing ddiclere thy acsestes taar components.
#
# Ideall once tout hecessy.
#
# The che boundaries during devicit do them together?
# Pro inody and other contexts.
#
# What components.
#
# Ideally, we should aim for
#
#
# iter :1260000, loss:0.052648
# e bour component's mepresitn youlicles map explicitly into the code. Yowicinc winit domactents wot your to underster, ableale bour acoup thaw dof your he bound rowe sista make to cray co be capturing
#
#
# iter :1260500, loss:0.053385
#  pouth ano cleasing that knowledge in your context frit yowe componed interfaces and inversion of control for low coupling.
#
# Low coupling means fewer interconnections across components. It means one c
#
#
# iter :1261000, loss:0.053323
# sig foupling ote componenderain youthinly oncensists or fow ba nor highly packa en erfeccing that.
#
# CTer context and on or could be capresion. Use well-defined interfaces and inversion of control for
#
#
# iter :1261500, loss:0.053035
# plitedotion al teint y. Produ access leqrer conner one hem nge weth cif your architectural idichingry ontext fry conseryriturcer of every public method of every class, write unit tests focusing on the
#
#
# iter :1262000, loss:0.053000
#  campo enkad is to make everything public! That is why codebases turn into a mass of interconnected objects.
#
# It's essential to organize your packages correctly. Packages should contain all classes of
#
#
# iter :1262500, loss:0.052734
# or even replaced without impacting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it will require clearly defin
#
#
# iter :1263000, loss:0.052631
# The yous wind iaglated.
#
# The more restricted your access level, the fewer chances to create unnecessary dependencies that will end up in a big ball of mud.
#
# We need to resist the temptation to make ev
#
#
# iter :1263500, loss:0.052390
# agl of o arcunctigl-defarce podeitesting
#
# Componenasis erelly.
#
# The basic summary of the story is that things get much easier to understand and maintain if your architectural ideas map explicitly into
#
#
# iter :1264000, loss:0.052290
# ed mound the ghim. The code to to rom Pach uthy romain know tos re smay toge and in ant mut inly oreat draylithings to ate cove and ro that will end up in a big ball of mud.
#
# We need to resist the tem
#
#
# iter :1264500, loss:0.052014
# ss withoup thowe smylconsersint code archings accend be capturing the domain knowledge in working code and protecting that knowledge in your context from contamination and overreaching from other cont
#
#
# iter :1265000, loss:0.052694
# till kout ro teatisis toflicents beve ather contexts.
#
# What do ProductRepository and BasketRepository have in comstsint an y are thould contain all y. Pund interfaces and inversion of control for low
#
#
# iter :1265500, loss:0.051665
# e your and ProductRepository are hrar. The code. Your code should rofury urict nes ancou haver components onces to kroupline demarcos componen ssams, snalle.
#
# We ne ms the ro unkeviog fo ever to laced
#
#
# iter :1266000, loss:0.052382
#  inveructs with a de thou nhar es components.
#
# Ideall of mmaclungr ou nhap exenfrurkcuches witigh ustess, prame he it yo? ding is turpote, and bou de ould context from contamination and overreaching f
#
#
# iter :1266500, loss:0.052297
# sig fofievery bnhy innt, whouct, ProductService, and ProductRepository are his with che bour codtig pofunderering ont xthy bould foundercably bnom thy sess code should contain all classes of a specifi
#
#
# iter :1267000, loss:0.052012
# plitedrore com thy unu h aen The component's public interface, covering every behaviour of the unit. Checkout my article about effective testing
#
# Components with a single, well-defined purpose are eas
#
#
# iter :1267500, loss:0.051952
#  simpontedyrallew components.
#
# Ideally, weptr romponething yrore hche toos the component's public interface, covering every behaviour of the unit. Checkout my article about effective testing
#
# Componen
#
#
# iter :1268000, loss:0.051699
# or even replaced without impacting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it will require clearly defin
#
#
# iter :1268500, loss:0.051576
# C. Punind leate uncomain if y iout youpine is tatint yo ot correblamrexp ext arr cohesion. Use well-defined interfaces and inversion of controlr ace ssadramponent our isichite, an and I hope cod is al
#
#
# iter :1269000, loss:0.051346
# a tu and Bas. bosstain mmog the code that changes together, stays together, carefully encapsulated.
#
# The more restrige couc ingitles mare te focected cound mampone cha sing Promuchandes oncess fucour
#
#
# iter :1269500, loss:0.051231
# ed mation ibte components, these components will inevitably interact with one another, and it will require clearly defined boundaries not to leak the domain. The result is a system that consists of co
#
#
# iter :1270000, loss:0.050966
# ss wut ithe domarcontext from togetes ancess is the cemponed pontsilg weys rull-defin th accom tha d bansext we rofunde, and ProductRepository are highly coupled; why would not you group them? Cohesio
#
#
# iter :1270500, loss:0.051640
# cramponendererasies llvill ing und coup controbly thaple ipent's public interface, covering every behaviour of the unu. The banncess mare reat inversion of control for low coupling.
#
# Low coupling mean
#
#
# iter :1271000, loss:0.050618
# aness, mositnos together, stays together, carefully encapsulare to incee ory as ancons.
#
# What do ProductRepository and BasketRepository have in common? Nothing. Both address different problems, so why
#
#
# iter :1271500, loss:0.051329
#  interacts with other components.
#
# Ideally, we should aim for high cohesion and low coupling. Apply the Single Responsibility Principle (SRP) for high cohesion. Use well-defined interfaces and inversi
#
#
# iter :1272000, loss:0.051238
# sig foupling ldomponntecting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it will require clearly defined bou
#
#
# iter :1272500, loss:0.050967
# pes your code acle one bavedint
#
#
#
# Low comcout ifhents.
#
# Ideally, we story is that things get much easier to understand and maintain if we can effectively draw and enforce boundaries during deve is on
#
#
# iter :1273000, loss:0.050902
#  comply.
#
# Coupling isitull-deperreinne tsithe domarly announces the reat things get much easier to understand and maintain if we can effectively draw and enforce boundaries during deve is onteraine Th
#
#
# iter :1273500, loss:0.050665
# or even replaced without impacting other components.
#
# When software is decomposed into smaller components, these components will inevitably interact with one another, and it will require clearly defin
#
#
# iter :1274000, loss:0.050538

# %%
rnn.predict(data_reader, 'get', 50)
# Out:
# 'geth w alys evilit madorkevy houpling. Apply the Sing'
